# %%
import pandas as pd
import nltk
import json
import string

# %%
from nltk.tokenize import TweetTokenizer
tknzr = TweetTokenizer()

from nltk.corpus import stopwords
stop = stopwords.words("english")

# %%
with open("example-corpus/doc1.json") as json_data:
    d = json.load(json_data)

# %%
doc1 = pd.DataFrame(columns=['ID', 'section-id', 'section', 'par-id', 'word', 'hl-id', 'is-annotation', 'tag'])
exclude = set(string.punctuation)

wid = 0
sid = 0
pid = 0
hlid = 0

for section, content in d.items():
    for par_type, text in content.items():       
        # add no-highlight text
        for par in [x for x in content.keys() if x[0]=="p"]:
            text = content[par]
            tokens = tknzr.tokenize(text)
            tokens = [word.lower() for word in tokens if word not in exclude]
            for token in tokens:
                doc1.loc[wid] = [wid, sid, section, pid, token, None, False, False]
                wid = wid + 1
            pid = pid + 1
                
    # add highlight text    
    for par in [x for x in content.keys() if x[0]=="h"]:
        text = content[par]
        tokens = tknzr.tokenize(text)
        tokens = [word.lower() for word in tokens if word not in exclude]

        for token in tokens:
            doc1.loc[wid] = [wid, sid, section, pid, token, hlid, False, False]
            wid = wid + 1

        if par[1:] not in hlids:
            hlids[par[1:]] = hlid 
        hlid = hlid + 1

    # add annotation text
    for par in [x for x in content.keys() if x[0]=="n"]:
        text = content[par]
        tokens = tknzr.tokenize(text)
        tokens = [word.lower() for word in tokens if word not in exclude]
        
        is_tag = False
        for token in tokens:
            if token[0] == "#":
                doc1.loc[wid] = [wid, sid, section, pid, token, hlids[par[1:]], True, True]
            else:
                doc1.loc[wid] = [wid, sid, section, pid, token, hlids[par[1:]], True, False]
            wid = wid + 1
        hlid = hlid + 1
    sid = sid + 1
    
print("finished")
# Out:
# finished

# %% [markdown]
# # The Tidy Data

# %%
doc1.sample(20)
# Out:
#         ID section-id   section par-id           word hl-id is-annotation  \
# 4271  4271          3        s2     54             on  None         False
# 195    195          0     intro      5        anybody  None         False
# 658    658          1        s1     11  behavioristic  None         False
# 939    939          1        s1     15        preface  None         False
# 2218  2218          1        s1     30            was  None         False
# 1046  1046          1        s1     16             by  None         False
# 2981  2981          1        s1     39             be  None         False
# 4393  4393          4  abstract     55    participate  None         False
# 2776  2776          1        s1     37             to  None         False
# 1405  1405          1        s1     20            ogy  None         False
# 86      86          0     intro      2           will  None         False
# 682    682          1        s1     11      standards  None         False
# 2752  2752          1        s1     37             in  None         False
# 1171  1171          1        s1     18         verbal  None         False
# 1629  1629          1        s1     23             to  None         False
# 677    677          1        s1     11  communication  None         False
# 663    663          1        s1     11              b  None         False
# 4242  4242          3        s2     54             of  None         False
# 2782  2782          1        s1     37             of  None         False
# 2733  2733          1        s1     36             so  None         False
#
#         tag
# 4271  False
# 195   False
# 658   False
# 939   False
# 2218  False
# 1046  False
# 2981  False
# 4393  False
# 2776  False
# 1405  False
# 86    False
# 682   False
# 2752  False
# 1171  False
# 1629  False
# 677   False
# 663   False
# 4242  False
# 2782  False
# 2733  False

# %% [markdown]
# # Show me all highlights

# %%
doc1[doc1['hl-id'].notnull()].groupby("hl-id")['word'].apply(lambda x: " ".join(x))
# Out:
# hl-id
# 0    at the time it was happening i did not realize...
# 2    they argued that mental events are not publicl...
# 3    a few years later b f skinner published verbal...
# 4    five years later inspired by such colleagues a...
# 6    mentalistic hypotheses about the cognitive pro...
# Name: word, dtype: object

# %% [markdown]
# # Show me all my annotations

# %%
doc1[doc1['is-annotation']].groupby("hl-id")['word'].apply(lambda x: " ".join(x))
# Out:
# hl-id
# 0    nobody was aware of the beginning of #cognitiv...
# 2    chomsky and bruner changed the game #surprise ...
# Name: word, dtype: object

# %% [markdown]
# # Show me tagged sections

# %%
sids = set(doc1[doc1.tag]['section-id'])
doc1[doc1['section-id'].isin(sids)].groupby("section-id")['word'].apply(lambda x: " ".join(x))
# Out:
# section-id
# 0    they unfolded concurrently but i will tell the...
# 1    in 1951 i apparently still hoped to gain scien...
# Name: word, dtype: object

# %% [markdown]
# # Plot of the most frequent words for each section

# %%
doc1.groupby("section")['word'].apply(lambda x: nltk.FreqDist(x))
# Out:
# section
# abstract  1950s                         1.0
#           a                             3.0
#           about                         1.0
#           account                       1.0
#           allocated                     1.0
#           and                           3.0
#           anthropology                  1.0
#           as                            1.0
#           becoming                      1.0
#           behaviorism                   1.0
#           called                        1.0
#           came                          1.0
#           child                         1.0
#           cially                        1.0
#           clear                         1.0
#           cognition                     1.0
#           cognitive                     2.0
#           coming                        1.0
#           computer                      1.0
#           could                         1.0
#           cru                           1.0
#           depended                      1.0
#           disciplines                   2.0
#           disciplines.collaboration     1.0
#           existence                     1.0
#           for                           1.0
#           freed                         1.0
#           from                          1.0
#           had                           1.0
#           how                           1.0
#                                        ...
# s2        them                          5.0
#           thenitive                     5.0
#           theory                       10.0
#           therefore                     5.0
#           they                          5.0
#           this                          2.0
#           those                         5.0
#           through                       1.0
#           to                           26.0
#           unable                        5.0
#           understood                    5.0
#           values                        5.0
#           verbal                        6.0
#           virtue                        5.0
#           was                          15.0
#           we                            6.0
#           were                          5.0
#           which                         5.0
#           with                          5.0
#           written                       5.0
#           years                         5.0
#           §                             1.0
#           –                             5.0
#           ’                            25.0
# title     a                             1.0
#           cognitive                     1.0
#           historical                    1.0
#           perspective                   1.0
#           revolution                    1.0
#           the                           1.0
# Name: word, Length: 462, dtype: float64

# %% [markdown]
# # Summary
#
# 1. Document Length
# 2. Vocabulary Density
# 3. Average Words Per Sentence
# 4. Most Frequent Words in the Corpus

# %% [markdown]
# # Tag Analysis
#
# ## Generic
#
# 1. Most common tags in documents
# 2. Tag distribution per document
# 3. "Trends" across documents
#
# ## Selected tags
#
# 1. Show individual tag distributions
#
# ## Tag correlations based on documents/proximity
